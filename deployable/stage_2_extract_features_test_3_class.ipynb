# %%
import os
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from essentials import resample_data, three_class_labels, two_class_labels, normalize
from features_acc_gyr_improved import GenerateFeatures 
import copy

# %% [markdown]
# Extract windowed features from the 3 axis of the accelerometer and the acceleration magnitude.
# 1. mean
# 2. rms
# 3. std
# 4. range
# 5. variance
# 6. min
# 7. max
# 8. time energy
# 9. spectral energy
# 10. permutation entropy
# 11. spectral entropy
# 12. spectral_centroid
# 13. spectral_spread
# 14. spectral_flatness
# 15. peak_frequency_ratio
# 16. hjorth_frequency
# 17. spectral_skewness
# 18. spectral_kurtosis
# 19. snr

# %% [markdown]
# ## Three (3) class data

# %%
with open('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/test_data_with_3_class_labels.pkl', 'rb') as f:
    test_data_3_class_labelled = pickle.load(f)

# %% [markdown]
# ## Data 1
# classes: void, non-void
#
# fs: original
#
# sliding window: 1s
#
# overlap: 0
#
# filename: two_class_1s_no.csv

# %%
#  do not upsample
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=1.0, overlap=0.0)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 13.34it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_1s_no.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       0.499464    0.000000   0.998928                   0.708341
# 1       1.498391    0.998928   1.997855                   0.867759
# 2       2.497319    1.997855   2.996783                   0.783083
# 3       3.496246    2.996783   3.995710                   0.843674
# 4       4.495174    3.995710   4.994638                   0.834573
# ..           ...         ...        ...                        ...
# 637    36.229895   35.733595  36.726195                   0.861280
# 638    37.222495   36.726195  37.718795                   0.885975
# 639    38.215095   37.718795  38.711394                   0.927914
# 640    39.207694   38.711394  39.703994                   0.914823
# 641    40.200294   39.703994  40.696594                   0.942786
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.485641   -0.285321   0.229972     0.856918   0.366463
# ...

# %% [markdown]
# ## Data 1b
# classes: void, non-void
#
# fs: original
#
# sliding window: 1s
#
# overlap: 0.5
#
# filename: two_class_1s_0.5.csv

# %%
#  do not upsample
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=1.0, overlap=0.5)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:01<00:00,  6.49it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_1s_0.5.csv', index=False)
final_features
# Out:
#       center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0        0.499464    0.000000   0.998928                   0.708341
# 1        1.007393    0.507929   1.506857                   0.757774
# 2        1.515322    1.015859   2.014786                   0.866209
# 3        2.023252    1.523788   2.522715                   0.852848
# 4        2.531181    2.031717   3.030645                   0.791533
# ...           ...         ...        ...                        ...
# 1272    38.711394   38.215095  39.207694                   0.959091
# 1273    39.207694   38.711394  39.703994                   0.914823
# 1274    39.703994   39.207694  40.200294                   0.931853
# 1275    40.200294   39.703994  40.696594                   0.942786
# 1276    40.696594   40.200294  41.192894                   0.856466
#
#       acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# ...

# %% [markdown]
# ## Data 1c
# classes: void, non-void
#
# fs: original
#
# sliding window: 1s
#
# overlap: 0.8
#
# filename: two_class_1s_0.8.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=1.0, overlap=0.8)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:02<00:00,  2.75it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_1s_0.8.csv', index=False)
final_features
# Out:
#       center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0        0.499464    0.000000   0.998928                   0.708341
# 1        0.702635    0.203172   1.202099                   0.655888
# 2        0.905807    0.406343   1.405271                   0.743236
# 3        1.108979    0.609515   1.608443                   0.778678
# 4        1.312151    0.812687   1.811614                   0.845735
# ...           ...         ...        ...                        ...
# 3171    39.803254   39.306954  40.299554                   0.954554
# 3172    40.001774   39.505474  40.498074                   0.949137
# 3173    40.200294   39.703994  40.696594                   0.942786
# 3174    40.398814   39.902514  40.895114                   0.915219
# 3175    40.597334   40.101034  41.093634                   0.900785
#
#       acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# ...

# %% [markdown]
# ## Data 2
# classes: void, non-void
#
# fs: original
#
# overlap: 0
#
# sliding window: 2s
#
# filename: two_class_2s_no.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=2.0, overlap=0.0)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 25.51it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_2s_no.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       0.998928    0.000000   1.997855                   0.805241
# 1       2.996783    1.997855   3.995710                   0.842921
# 2       4.994638    3.995710   5.993565                   0.842683
# 3       6.992493    5.993565   7.991420                   0.865196
# 4       8.990348    7.991420   9.989275                   0.883331
# ..           ...         ...        ...                        ...
# 311    31.027017   30.026146  32.027889                   0.901531
# 312    33.028760   32.027889  34.029632                   0.918177
# 313    35.030503   34.029632  36.031375                   0.890261
# 314    37.032246   36.031375  38.033118                   0.881252
# 315    39.033989   38.033118  40.034861                   0.938400
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.558966   -0.099222   0.252002     0.856918   0.270832
# ...

# %% [markdown]
# ## Data 2b
# classes: void, non-void
#
# fs: original
#
# overlap: 0.5
#
# sliding window: 2s
#
# filename: two_class_2s_0.5.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=2.0, overlap=0.5)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 12.75it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_2s_0.5.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       0.998928    0.000000   1.997855                   0.805241
# 1       1.997855    0.998928   2.996783                   0.835954
# 2       2.996783    1.997855   3.995710                   0.842921
# 3       3.995710    2.996783   4.994638                   0.858970
# 4       4.994638    3.995710   5.993565                   0.842683
# ..           ...         ...        ...                        ...
# 627    35.741867   34.740995  36.742738                   0.888845
# 628    36.734466   35.733595  37.735338                   0.872707
# 629    37.727066   36.726195  38.727938                   0.914484
# 630    38.719666   37.718795  39.720538                   0.927706
# 631    39.712266   38.711394  40.713138                   0.927846
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.558966   -0.099222   0.252002     0.856918   0.270832
# ...

# %% [markdown]
# ## Data 2c
# classes: void, non-void
#
# fs: original
#
# overlap: 0.8
#
# sliding window: 2s
#
# filename: two_class_2s_0.8.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=2.0, overlap=0.8)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:01<00:00,  5.53it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_2s_0.8.csv', index=False)
final_features
# Out:
#       center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0        0.998928    0.000000   1.997855                   0.805241
# 1        1.405271    0.406343   2.404199                   0.809914
# 2        1.811614    0.812687   2.810542                   0.837445
# 3        2.217958    1.219030   3.216885                   0.858914
# 4        2.624301    1.625374   3.623229                   0.842207
# ...           ...         ...        ...                        ...
# 1561    38.322626   37.321755  39.323498                   0.911384
# 1562    38.719666   37.718795  39.720538                   0.927706
# 1563    39.116706   38.115835  40.117578                   0.941672
# 1564    39.513746   38.512875  40.514618                   0.943597
# 1565    39.910786   38.909914  40.911658                   0.892796
#
#       acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# ...

# %% [markdown]
# ## Data 3
# classes: void, non-void
#
# fs: original
#
# overlap: 0
#
# sliding window: 3s
#
# filename: two_class_3s_no.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=3.0, overlap=0.0)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 40.01it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_3s_no.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       1.498391    0.000000   2.996783                   0.811911
# 1       4.495174    2.996783   5.993565                   0.858321
# 2       7.491957    5.993565   8.990348                   0.867915
# 3      10.488739    8.990348  11.987131                   0.889524
# 4      13.485522   11.987131  14.983913                   0.909840
# ..           ...         ...        ...                        ...
# 206    25.451915   23.954743  26.949086                   0.908979
# 207    28.446258   26.949086  29.943429                   0.894037
# 208    31.440601   29.943429  32.937772                   0.892781
# 209    34.434943   32.937772  35.932115                   0.916184
# 210    37.429286   35.932115  38.926458                   0.917341
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.607805   -0.037460   0.238700     1.056555   0.241622
# ...

# %% [markdown]
# ## Data 3b
# classes: void, non-void
#
# fs: original
#
# overlap: 0.5
#
# sliding window: 3s
#
# filename: two_class_3s_0.5.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=3.0, overlap=0.5)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 20.29it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_3s_0.5.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       1.498391    0.000000   2.996783                   0.811911
# 1       2.988317    1.489926   4.486708                   0.857879
# 2       4.478243    2.979852   5.976634                   0.853485
# 3       5.968169    4.469778   7.466560                   0.852683
# 4       7.458095    5.959703   8.956486                   0.866483
# ..           ...         ...        ...                        ...
# 412    32.764067   31.266896  34.261238                   0.912435
# 413    34.252967   32.755795  35.750138                   0.913703
# 414    35.741867   34.244695  37.239038                   0.890806
# 415    37.230766   35.733595  38.727938                   0.899544
# 416    38.719666   37.222495  40.216838                   0.928936
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.607805   -0.037460   0.238700     1.056555   0.241622
# ...

# %% [markdown]
# ## Data 3c
# classes: void, non-void
#
# fs: original
#
# overlap: 0.8
#
# sliding window: 3s
#
# filename: two_class_3s_0.8.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=3.0, overlap=0.8)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00,  8.30it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_3s_0.8.csv', index=False)
final_features
# Out:
#       center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0        1.498391    0.000000   2.996783                   0.811911
# 1        2.090975    0.592584   3.589367                   0.827972
# 2        2.683560    1.185168   4.181951                   0.876040
# 3        3.276144    1.777752   4.774535                   0.843118
# 4        3.868728    2.370337   5.367119                   0.849080
# ...           ...         ...        ...                        ...
# 1036    37.230766   35.733595  38.727938                   0.899544
# 1037    37.826326   36.329155  39.323498                   0.919431
# 1038    38.421886   36.924715  39.919058                   0.921653
# 1039    39.017446   37.520275  40.514618                   0.934054
# 1040    39.613006   38.115835  41.110177                   0.930148
#
#       acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# ...

# %% [markdown]
# ## Data 4
# classes: void, non-void
#
# fs: original
#
# overlap: 0.0
#
# sliding window: 4s
#
# filename: two_class_4s_no.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=4.0, overlap=0.0)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 48.70it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_4s_no.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       1.997855    0.000000   3.995710                   0.825847
# 1       5.993565    3.995710   7.991420                   0.856235
# 2       9.989275    7.991420  11.987131                   0.887661
# 3      13.984986   11.987131  15.982841                   0.912659
# 4      17.980696   15.982841  19.978551                   0.939942
# ..           ...         ...        ...                        ...
# 150    22.019174   20.017430  24.020917                   0.932078
# 151    26.022660   24.020917  28.024403                   0.893574
# 152    30.026146   28.024403  32.027889                   0.908206
# 153    34.029632   32.027889  36.031375                   0.907581
# 154    38.033118   36.031375  40.034861                   0.914393
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.644293   -0.013293   0.211426     1.056555   0.211843
# ...

# %% [markdown]
# ## Data 4b
# classes: void, non-void
#
# fs: original
#
# overlap: 0.5
#
# sliding window: 4s
#
# filename: two_class_4s_0.5.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=4.0, overlap=0.5)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 27.89it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_4s_0.5.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       1.997855    0.000000   3.995710                   0.825847
# 1       3.995710    1.997855   5.993565                   0.848527
# 2       5.993565    3.995710   7.991420                   0.856235
# 3       7.991420    5.993565   9.989275                   0.872985
# 4       9.989275    7.991420  11.987131                   0.887661
# ..           ...         ...        ...                        ...
# 302    30.026146   28.024403  32.027889                   0.908206
# 303    32.027889   30.026146  34.029632                   0.908532
# 304    34.029632   32.027889  36.031375                   0.907581
# 305    36.031375   34.029632  38.033118                   0.887310
# 306    38.033118   36.031375  40.034861                   0.914393
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.644293   -0.013293   0.211426     1.056555   0.211843
# ...

# %% [markdown]
# ## Data 4c
# classes: void, non-void
#
# fs: original
#
# overlap: 0.8
#
# sliding window: 4s
#
# filename: two_class_4s_0.8.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=4.0, overlap=0.8)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 11.15it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_4s_0.8.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       1.997855    0.000000   3.995710                   0.825847
# 1       2.793611    0.795756   4.791466                   0.845330
# 2       3.589367    1.591512   5.587222                   0.849058
# 3       4.385123    2.387268   6.382978                   0.851907
# 4       5.180878    3.183023   7.178734                   0.860105
# ..           ...         ...        ...                        ...
# 763    35.353098   33.351355  37.354841                   0.900031
# 764    36.147178   34.145435  38.148921                   0.889898
# 765    36.941258   34.939515  38.943001                   0.915174
# 766    37.735338   35.733595  39.737081                   0.908062
# 767    38.529418   36.527675  40.531161                   0.934187
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.644293   -0.013293   0.211426     1.056555   0.211843
# ...

# %% [markdown]
# ## Data 5
# classes: void, non-void
#
# fs: original
#
# overlap: 0.0
#
# sliding window: 5s
#
# filename: two_class_5s_no.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=5.0, overlap=0.0)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 62.25it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_5s_no.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       2.497319    0.000000   4.994638                   0.833939
# 1       7.491957    4.994638   9.989275                   0.868767
# 2      12.486594    9.989275  14.983913                   0.905050
# 3      17.481232   14.983913  19.978551                   0.937051
# 4      22.475870   19.978551  24.973189                   0.881799
# ..           ...         ...        ...                        ...
# 119    17.486301   14.988258  19.984344                   0.933870
# 120    22.482387   19.984344  24.980430                   0.927374
# 121    27.478473   24.980430  29.976516                   0.896290
# 122    32.474559   29.976516  34.972602                   0.901525
# 123    37.470645   34.972602  39.968688                   0.913730
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.658774    0.004541   0.199449     1.092786   0.199501
# ...

# %% [markdown]
# ## Data 5b
# classes: void, non-void
#
# fs: original
#
# overlap: 0.5
#
# sliding window: 5s
#
# filename: two_class_5s_0.5.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=5.0, overlap=0.5)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 33.82it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_5s_0.5.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       2.497319    0.000000   4.994638                   0.833939
# 1       5.003103    2.505784   7.500422                   0.860111
# 2       7.508888    5.011569  10.006206                   0.871297
# 3      10.014672    7.517353  12.511991                   0.894085
# 4      12.520456   10.023137  15.017775                   0.902519
# ..           ...         ...        ...                        ...
# 238    27.478473   24.980430  29.976516                   0.896290
# 239    29.976516   27.478473  32.474559                   0.890419
# 240    32.474559   29.976516  34.972602                   0.901525
# 241    34.972602   32.474559  37.470645                   0.910231
# 242    37.470645   34.972602  39.968688                   0.913730
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.658774    0.004541   0.199449     1.092786   0.199501
# ...

# %% [markdown]
# ## Data 5c
# classes: void, non-void
#
# fs: original
#
# overlap: 0.8
#
# sliding window: 5s
#
# filename: two_class_5s_0.8.csv

# %%
all_features = []
for i, exp_id in enumerate(test_data_3_class_labelled.keys()):    
    # Extract features
    
    df = test_data_3_class_labelled[exp_id]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=5.0, overlap=0.8)
    features, _ = analyzer.analyze_multi_axis_imu(test_data_3_class_labelled[exp_id])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id 
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# ...
# Analyzing : 100%|██████████| 8/8 [00:00<00:00, 13.71it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/deployable/data/extracted_features_data/3_class/test_set/two_class_5s_0.8.csv', index=False)
final_features
# Out:
#      center_time  start_time   end_time  acc_x_permutation_entropy  \
# 0       2.497319    0.000000   4.994638                   0.833939
# 1       3.496246    0.998928   5.993565                   0.852163
# 2       4.495174    1.997855   6.992493                   0.850384
# 3       5.494102    2.996783   7.991420                   0.862116
# 4       6.493029    3.995710   8.990348                   0.860244
# ..           ...         ...        ...                        ...
# 600    34.261238   31.763195  36.759281                   0.900708
# 601    35.253838   32.755795  37.751881                   0.903151
# 602    36.246438   33.748395  38.744481                   0.906503
# 603    37.239038   34.740995  39.737081                   0.905755
# 604    38.231638   35.733595  40.729681                   0.918521
#
#      acc_x_spectral_entropy  acc_x_mean  acc_x_std  acc_x_range  acc_x_rms  \
# 0                  0.658774    0.004541   0.199449     1.092786   0.199501
# ...
