# %%
import os
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, roc_auc_score, precision_recall_fscore_support
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GroupKFold
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks
from imblearn.combine import SMOTETomek
import itertools

# %%
files = ['two_class_raw_1s_no.csv', 'two_class_raw_1s_yo_0.5.csv', 'two_class_raw_1s_yo_0.8.csv', 'two_class_raw_2s_no.csv', 'two_class_raw_2s_yo_0.5.csv', 'two_class_raw_2s_yo_0.8.csv', 
        'two_class_raw_3s_no.csv', 'two_class_raw_3s_yo_0.5.csv', 'two_class_raw_3s_yo_0.8.csv', 'two_class_raw_4s_no.csv', 'two_class_raw_4s_yo_0.5.csv', 'two_class_raw_4s_yo_0.8.csv',
        'two_class_raw_5s_no.csv', 'two_class_raw_5s_yo_0.5.csv', 'two_class_raw_5s_yo_0.8.csv']

base_path = '/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/improved_features_data_main/'

# %%
class_names = ['void', 'non-void']

# %%
def generate_confusion_matrix(cnf_matrix, classes, normalize=False, title='Confusion matrix'):
    plt.imshow(cnf_matrix, interpolation='nearest', cmap=plt.get_cmap())
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cnf_matrix.max() / 2.

    for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
        plt.text(j, i, format(cnf_matrix[i, j], fmt), horizontalalignment="center",
                color="black" if cnf_matrix[i, j] > thresh else "yellow")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    return cnf_matrix

# %%
def plot_confusion_matrix(predicted_labels_list, y_test_list, strategy_name, exp_name):
    cnf_matrix = confusion_matrix(y_test_list, predicted_labels_list, labels=class_names)
    np.set_printoptions(precision=2)

    # Plot non-normalized confusion matrix
    plt.figure()
    generate_confusion_matrix(cnf_matrix, classes=class_names, title=f'XGBoost - {exp_name}({strategy_name})')
    file_name = f'cv-cm_{exp_name}_{strategy_name}.png'
    plt.savefig(f'/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/XGBoost/2_class/cv-conf-mat/{file_name}')
    plt.show()

# %%
def compare_sampling_techniques(X, y, groups, exp_name, random_state=42):
    """
    Compare different sampling techniques for imbalanced classification
    """
    
    # Define sampling strategies to test
    sampling_strategies = {
        'none': None,
        'oversample_smote': SMOTE(random_state=random_state),
        'undersample_tomek_links': TomekLinks(),
        'combined_smote_tomek': SMOTETomek(random_state=random_state)
    }
    
    results = {}
    
    for strategy_name, sampler in sampling_strategies.items():
        print(f"\nTesting {strategy_name}...")
        
        # Cross-validation setup
        gkf = GroupKFold(n_splits=10) 
        fold_results = []
        
        # For confusion matrix
        predicted_targets = np.array([])
        actual_targets = np.array([])
        
        for fold_num, (train_idx_fold, test_idx_fold) in enumerate(gkf.split(X, y, groups)):
            X_train_fold, X_test_fold = X.iloc[train_idx_fold], X.iloc[test_idx_fold]
            y_train_fold, y_test_fold = y.iloc[train_idx_fold], y.iloc[test_idx_fold]

            
            # Apply sampling (if any)
            if sampler is not None:
                try:
                    X_train_resampled, y_train_resampled = sampler.fit_resample(X_train_fold, y_train_fold)
                    X_train_resampled = pd.DataFrame(X_train_resampled, columns=X_train_fold.columns)
                    y_train_resampled = pd.Series(y_train_resampled)
                except Exception as e:
                    print(f"Sampling failed for {strategy_name}: {e}")
                    continue
            else:
                X_train_resampled = X_train_fold
                y_train_resampled = y_train_fold
            
            # Use XGBoost with DEFAULT parameters
            model = XGBClassifier(
                random_state=random_state,
                eval_metric='logloss',  # Suppress warning
            )
            
            # Encode labels
            label_encoder = LabelEncoder()
            y_train_encoded = label_encoder.fit_transform(y_train_resampled)
            
            # Fit model
            model.fit(X_train_resampled, y_train_encoded)
            
            # Predict
            predictions = label_encoder.inverse_transform(model.predict(X_test_fold))
            
            # For confusion matrix
            predicted_targets = np.append(predicted_targets, predictions)
            actual_targets = np.append(actual_targets, y_test_fold)
        plot_confusion_matrix(predicted_targets, actual_targets,strategy_name, exp_name)

# %%
file_results = {}
for file in tqdm(files, desc="Generating confusion matrices from the cross validation results"):
    data_path = os.path.join(base_path, file)
    features = pd.read_csv(data_path)
    features.drop(['center_time', 'start_time', 'end_time'], axis=1, inplace=True)
    details = file.split('_')
    exp_name = f"{details[3]}_{details[-1].replace('.csv', '')}"
    print(f"Analysing {exp_name}")
    
    # split data
    X = features.drop(columns=['label', 'experiment_id'])
    y = features['label']
    groups = features['experiment_id']
    
    compare_sampling_techniques(X, y, groups, exp_name, 42)
# Out:
# Generating confusion matrices from the cross validation results:   0%|          | 0/15 [00:00<?, ?it/s]
# Analysing 1s_no
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:   7%|▋         | 1/15 [00:48<11:21, 48.70s/it]
# Analysing 1s_0.5
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  13%|█▎        | 2/15 [01:49<12:09, 56.08s/it]
# Analysing 1s_0.8
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  20%|██        | 3/15 [03:06<13:05, 65.45s/it]
# Analysing 2s_no
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  27%|██▋       | 4/15 [03:38<09:32, 52.04s/it]
# Analysing 2s_0.5
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  33%|███▎      | 5/15 [04:20<08:05, 48.59s/it]
# Analysing 2s_0.8
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  40%|████      | 6/15 [05:17<07:41, 51.28s/it]
# Analysing 3s_no
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  47%|████▋     | 7/15 [05:39<05:34, 41.87s/it]
# Analysing 3s_0.5
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  53%|█████▎    | 8/15 [06:12<04:32, 38.90s/it]
# Analysing 3s_0.8
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  60%|██████    | 9/15 [07:00<04:10, 41.74s/it]
# Analysing 4s_no
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  67%|██████▋   | 10/15 [07:41<03:28, 41.71s/it]
# Analysing 4s_0.5
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  73%|███████▎  | 11/15 [08:02<02:20, 35.24s/it]
# Analysing 4s_0.8
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  80%|████████  | 12/15 [08:45<01:52, 37.59s/it]
# Analysing 5s_no
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  87%|████████▋ | 13/15 [09:02<01:03, 31.57s/it]
# Analysing 5s_0.5
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results:  93%|█████████▎| 14/15 [09:27<00:29, 29.45s/it]
# Analysing 5s_0.8
#
# Testing none...
# Testing oversample_smote...
# Testing undersample_tomek_links...
# Testing combined_smote_tomek...
# Generating confusion matrices from the cross validation results: 100%|██████████| 15/15 [10:05<00:00, 40.37s/it]

# %% [markdown]
# ### Classification report

# %%
def print_classification_report(y_test, y_pred, strategy_name, exp_name):
    report = classification_report(y_test, y_pred, labels=class_names)

    print(f'Classification report: XGBoost {exp_name}({strategy_name})')
    print(report)

# %%
def compare_sampling_techniques_classification_report(X, y, groups, exp_name, random_state=42):
    """
    Compare different sampling techniques for imbalanced classification
    """
    
    # Define sampling strategies to test
    sampling_strategies = {
        'none': None,
        'oversample_smote': SMOTE(random_state=random_state),
        'undersample_tomek_links': TomekLinks(),
        'combined_smote_tomek': SMOTETomek(random_state=random_state)
    }
    
    results = {}
    
    for strategy_name, sampler in sampling_strategies.items():
        print(f"\nTesting {strategy_name}...")
        
        # Cross-validation setup
        gkf = GroupKFold(n_splits=10) 
        fold_results = []
        
        # For confusion matrix
        predicted_targets = np.array([])
        actual_targets = np.array([])
        
        for fold_num, (train_idx_fold, test_idx_fold) in enumerate(gkf.split(X, y, groups)):
            X_train_fold, X_test_fold = X.iloc[train_idx_fold], X.iloc[test_idx_fold]
            y_train_fold, y_test_fold = y.iloc[train_idx_fold], y.iloc[test_idx_fold]

            
            # Apply sampling (if any)
            if sampler is not None:
                try:
                    X_train_resampled, y_train_resampled = sampler.fit_resample(X_train_fold, y_train_fold)
                    X_train_resampled = pd.DataFrame(X_train_resampled, columns=X_train_fold.columns)
                    y_train_resampled = pd.Series(y_train_resampled)
                except Exception as e:
                    print(f"Sampling failed for {strategy_name}: {e}")
                    continue
            else:
                X_train_resampled = X_train_fold
                y_train_resampled = y_train_fold
            
            # Use XGBoost with DEFAULT parameters
            model = XGBClassifier(
                random_state=random_state,
                eval_metric='logloss',  # Suppress warning
            )
            
            # Encode labels
            label_encoder = LabelEncoder()
            y_train_encoded = label_encoder.fit_transform(y_train_resampled)
            
            # Fit model
            model.fit(X_train_resampled, y_train_encoded)
            
            # Predict
            predictions = label_encoder.inverse_transform(model.predict(X_test_fold))
            
            # For confusion matrix
            predicted_targets = np.append(predicted_targets, predictions)
            actual_targets = np.append(actual_targets, y_test_fold)
        print_classification_report(predicted_targets, actual_targets,strategy_name, exp_name)

# %%
file_results = {}
for file in tqdm(files, desc="Generating classification reports from the cross validation results"):
    data_path = os.path.join(base_path, file)
    features = pd.read_csv(data_path)
    features.drop(['center_time', 'start_time', 'end_time'], axis=1, inplace=True)
    details = file.split('_')
    exp_name = f"{details[3]}_{details[-1].replace('.csv', '')}"
    print(f"Analysing {exp_name}")
    
    # split data
    X = features.drop(columns=['label', 'experiment_id'])
    y = features['label']
    groups = features['experiment_id']
    
    compare_sampling_techniques_classification_report(X, y, groups, exp_name, 42)
# Out:
# Generating classification reports from the cross validation results:   0%|          | 0/15 [00:00<?, ?it/s]
# Analysing 1s_no
#
# Testing none...
# Classification report: XGBoost 1s_no(none)
#               precision    recall  f1-score   support
#
#         void       0.54      0.60      0.57       861
#     non-void       0.76      0.71      0.74      1551
#
#     accuracy                           0.67      2412
#    macro avg       0.65      0.66      0.65      2412
# weighted avg       0.68      0.67      0.67      2412
#
#
# Testing oversample_smote...
# Classification report: XGBoost 1s_no(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.58      0.60      0.59       933
#     non-void       0.74      0.73      0.73      1479
#
#     accuracy                           0.68      2412
#    macro avg       0.66      0.66      0.66      2412
# weighted avg       0.68      0.68      0.68      2412
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 1s_no(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.61      0.59      0.60       993
#     non-void       0.72      0.74      0.73      1419
#
#     accuracy                           0.68      2412
#    macro avg       0.67      0.66      0.67      2412
# weighted avg       0.68      0.68      0.68      2412
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:   7%|▋         | 1/15 [00:56<13:06, 56.15s/it]
# Classification report: XGBoost 1s_no(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.59      0.61      0.60       927
#     non-void       0.75      0.73      0.74      1485
#
#     accuracy                           0.69      2412
#    macro avg       0.67      0.67      0.67      2412
# weighted avg       0.69      0.69      0.69      2412
#
# Analysing 1s_0.5
#
# Testing none...
# Classification report: XGBoost 1s_0.5(none)
#               precision    recall  f1-score   support
#
#         void       0.52      0.60      0.56      1696
#     non-void       0.77      0.71      0.74      3161
#
#     accuracy                           0.67      4857
#    macro avg       0.65      0.65      0.65      4857
# weighted avg       0.68      0.67      0.67      4857
#
#
# Testing oversample_smote...
# Classification report: XGBoost 1s_0.5(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.58      0.59      0.59      1910
#     non-void       0.73      0.72      0.73      2947
#
#     accuracy                           0.67      4857
#    macro avg       0.66      0.66      0.66      4857
# weighted avg       0.67      0.67      0.67      4857
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 1s_0.5(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.57      0.60      0.59      1860
#     non-void       0.74      0.72      0.73      2997
#
#     accuracy                           0.68      4857
#    macro avg       0.66      0.66      0.66      4857
# weighted avg       0.68      0.68      0.68      4857
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  13%|█▎        | 2/15 [01:59<13:08, 60.63s/it]
# Classification report: XGBoost 1s_0.5(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.58      0.59      0.59      1916
#     non-void       0.73      0.72      0.73      2941
#
#     accuracy                           0.67      4857
#    macro avg       0.66      0.66      0.66      4857
# weighted avg       0.67      0.67      0.67      4857
#
# Analysing 1s_0.8
#
# Testing none...
# Classification report: XGBoost 1s_0.8(none)
#               precision    recall  f1-score   support
#
#         void       0.50      0.60      0.55      4395
#     non-void       0.77      0.70      0.73      8519
#
#     accuracy                           0.66     12914
#    macro avg       0.64      0.65      0.64     12914
# weighted avg       0.68      0.66      0.67     12914
#
#
# Testing oversample_smote...
# Classification report: XGBoost 1s_0.8(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.59      0.61      0.60      5048
#     non-void       0.75      0.73      0.74      7866
#
#     accuracy                           0.68     12914
#    macro avg       0.67      0.67      0.67     12914
# weighted avg       0.69      0.68      0.68     12914
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 1s_0.8(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.53      0.60      0.56      4565
#     non-void       0.76      0.70      0.73      8349
#
#     accuracy                           0.67     12914
#    macro avg       0.64      0.65      0.65     12914
# weighted avg       0.68      0.67      0.67     12914
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  20%|██        | 3/15 [03:34<15:13, 76.16s/it]
# Classification report: XGBoost 1s_0.8(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.56      0.60      0.58      4926
#     non-void       0.74      0.72      0.73      7988
#
#     accuracy                           0.67     12914
#    macro avg       0.65      0.66      0.65     12914
# weighted avg       0.67      0.67      0.67     12914
#
# Analysing 2s_no
#
# Testing none...
# Classification report: XGBoost 2s_no(none)
#               precision    recall  f1-score   support
#
#         void       0.54      0.63      0.58       412
#     non-void       0.79      0.72      0.75       781
#
#     accuracy                           0.69      1193
#    macro avg       0.66      0.68      0.67      1193
# weighted avg       0.70      0.69      0.69      1193
#
#
# Testing oversample_smote...
# Classification report: XGBoost 2s_no(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.58      0.62      0.60       448
#     non-void       0.76      0.73      0.74       745
#
#     accuracy                           0.69      1193
#    macro avg       0.67      0.67      0.67      1193
# weighted avg       0.69      0.69      0.69      1193
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 2s_no(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.61      0.62      0.62       473
#     non-void       0.75      0.74      0.75       720
#
#     accuracy                           0.69      1193
#    macro avg       0.68      0.68      0.68      1193
# weighted avg       0.70      0.69      0.70      1193
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  27%|██▋       | 4/15 [04:09<10:59, 59.91s/it]
# Classification report: XGBoost 2s_no(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.61      0.64      0.62       459
#     non-void       0.77      0.75      0.76       734
#
#     accuracy                           0.70      1193
#    macro avg       0.69      0.69      0.69      1193
# weighted avg       0.71      0.70      0.71      1193
#
# Analysing 2s_0.5
#
# Testing none...
# Classification report: XGBoost 2s_0.5(none)
#               precision    recall  f1-score   support
#
#         void       0.54      0.62      0.58       834
#     non-void       0.78      0.71      0.74      1537
#
#     accuracy                           0.68      2371
#    macro avg       0.66      0.67      0.66      2371
# weighted avg       0.69      0.68      0.69      2371
#
#
# Testing oversample_smote...
# Classification report: XGBoost 2s_0.5(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.60      0.63      0.61       912
#     non-void       0.76      0.74      0.75      1459
#
#     accuracy                           0.69      2371
#    macro avg       0.68      0.68      0.68      2371
# weighted avg       0.70      0.69      0.69      2371
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 2s_0.5(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.62      0.62      0.62       954
#     non-void       0.75      0.74      0.75      1417
#
#     accuracy                           0.70      2371
#    macro avg       0.68      0.68      0.68      2371
# weighted avg       0.70      0.70      0.70      2371
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  33%|███▎      | 5/15 [05:13<10:15, 61.51s/it]
# Classification report: XGBoost 2s_0.5(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.60      0.62      0.61       916
#     non-void       0.76      0.73      0.75      1455
#
#     accuracy                           0.69      2371
#    macro avg       0.68      0.68      0.68      2371
# weighted avg       0.69      0.69      0.69      2371
#
# Analysing 2s_0.8
#
# Testing none...
# Classification report: XGBoost 2s_0.8(none)
#               precision    recall  f1-score   support
#
#         void       0.55      0.62      0.58      2200
#     non-void       0.77      0.71      0.74      3879
#
#     accuracy                           0.68      6079
#    macro avg       0.66      0.67      0.66      6079
# weighted avg       0.69      0.68      0.68      6079
#
#
# Testing oversample_smote...
# Classification report: XGBoost 2s_0.8(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.58      0.63      0.60      2303
#     non-void       0.76      0.72      0.74      3776
#
#     accuracy                           0.69      6079
#    macro avg       0.67      0.67      0.67      6079
# weighted avg       0.69      0.69      0.69      6079
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 2s_0.8(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.55      0.63      0.58      2177
#     non-void       0.77      0.71      0.74      3902
#
#     accuracy                           0.68      6079
#    macro avg       0.66      0.67      0.66      6079
# weighted avg       0.69      0.68      0.68      6079
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  40%|████      | 6/15 [06:08<08:51, 59.04s/it]
# Classification report: XGBoost 2s_0.8(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.56      0.62      0.59      2272
#     non-void       0.76      0.71      0.73      3807
#
#     accuracy                           0.68      6079
#    macro avg       0.66      0.66      0.66      6079
# weighted avg       0.68      0.68      0.68      6079
#
# Analysing 3s_no
#
# Testing none...
# Classification report: XGBoost 3s_no(none)
#               precision    recall  f1-score   support
#
#         void       0.57      0.64      0.61       288
#     non-void       0.78      0.72      0.75       501
#
#     accuracy                           0.69       789
#    macro avg       0.68      0.68      0.68       789
# weighted avg       0.70      0.69      0.70       789
#
#
# Testing oversample_smote...
# Classification report: XGBoost 3s_no(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.62      0.63      0.62       317
#     non-void       0.75      0.74      0.74       472
#
#     accuracy                           0.69       789
#    macro avg       0.68      0.68      0.68       789
# weighted avg       0.69      0.69      0.69       789
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 3s_no(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.64      0.63      0.64       328
#     non-void       0.74      0.75      0.75       461
#
#     accuracy                           0.70       789
#    macro avg       0.69      0.69      0.69       789
# weighted avg       0.70      0.70      0.70       789
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  47%|████▋     | 7/15 [06:25<06:02, 45.36s/it]
# Classification report: XGBoost 3s_no(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.65      0.64      0.65       325
#     non-void       0.75      0.75      0.75       464
#
#     accuracy                           0.71       789
#    macro avg       0.70      0.70      0.70       789
# weighted avg       0.71      0.71      0.71       789
#
# Analysing 3s_0.5
#
# Testing none...
# Classification report: XGBoost 3s_0.5(none)
#               precision    recall  f1-score   support
#
#         void       0.54      0.61      0.57       573
#     non-void       0.75      0.70      0.73       987
#
#     accuracy                           0.67      1560
#    macro avg       0.65      0.65      0.65      1560
# weighted avg       0.68      0.67      0.67      1560
#
#
# Testing oversample_smote...
# Classification report: XGBoost 3s_0.5(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.58      0.60      0.59       627
#     non-void       0.73      0.71      0.72       933
#
#     accuracy                           0.67      1560
#    macro avg       0.66      0.66      0.66      1560
# weighted avg       0.67      0.67      0.67      1560
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 3s_0.5(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.61      0.61      0.61       638
#     non-void       0.73      0.72      0.73       922
#
#     accuracy                           0.68      1560
#    macro avg       0.67      0.67      0.67      1560
# weighted avg       0.68      0.68      0.68      1560
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  53%|█████▎    | 8/15 [06:48<04:27, 38.21s/it]
# Classification report: XGBoost 3s_0.5(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.62      0.63      0.63       641
#     non-void       0.74      0.74      0.74       919
#
#     accuracy                           0.69      1560
#    macro avg       0.68      0.68      0.68      1560
# weighted avg       0.69      0.69      0.69      1560
#
# Analysing 3s_0.8
#
# Testing none...
# Classification report: XGBoost 3s_0.8(none)
#               precision    recall  f1-score   support
#
#         void       0.52      0.63      0.57      1340
#     non-void       0.78      0.70      0.74      2550
#
#     accuracy                           0.67      3890
#    macro avg       0.65      0.66      0.65      3890
# weighted avg       0.69      0.67      0.68      3890
#
#
# Testing oversample_smote...
# Classification report: XGBoost 3s_0.8(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.57      0.62      0.59      1503
#     non-void       0.75      0.71      0.73      2387
#
#     accuracy                           0.67      3890
#    macro avg       0.66      0.66      0.66      3890
# weighted avg       0.68      0.67      0.68      3890
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 3s_0.8(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.57      0.62      0.59      1469
#     non-void       0.76      0.71      0.73      2421
#
#     accuracy                           0.68      3890
#    macro avg       0.66      0.67      0.66      3890
# weighted avg       0.68      0.68      0.68      3890
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  60%|██████    | 9/15 [07:23<03:44, 37.39s/it]
# Classification report: XGBoost 3s_0.8(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.57      0.61      0.59      1518
#     non-void       0.74      0.71      0.72      2372
#
#     accuracy                           0.67      3890
#    macro avg       0.66      0.66      0.66      3890
# weighted avg       0.67      0.67      0.67      3890
#
# Analysing 4s_no
#
# Testing none...
# Classification report: XGBoost 4s_no(none)
#               precision    recall  f1-score   support
#
#         void       0.58      0.60      0.59       230
#     non-void       0.74      0.72      0.73       355
#
#     accuracy                           0.67       585
#    macro avg       0.66      0.66      0.66       585
# weighted avg       0.68      0.67      0.67       585
#
#
# Testing oversample_smote...
# Classification report: XGBoost 4s_no(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.62      0.60      0.61       244
#     non-void       0.72      0.73      0.72       341
#
#     accuracy                           0.68       585
#    macro avg       0.67      0.67      0.67       585
# weighted avg       0.68      0.68      0.68       585
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 4s_no(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.63      0.61      0.62       244
#     non-void       0.73      0.74      0.73       341
#
#     accuracy                           0.69       585
#    macro avg       0.68      0.68      0.68       585
# weighted avg       0.69      0.69      0.69       585
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  67%|██████▋   | 10/15 [07:35<02:27, 29.57s/it]
# Classification report: XGBoost 4s_no(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.63      0.62      0.63       244
#     non-void       0.73      0.74      0.74       341
#
#     accuracy                           0.69       585
#    macro avg       0.68      0.68      0.68       585
# weighted avg       0.69      0.69      0.69       585
#
# Analysing 4s_0.5
#
# Testing none...
# Classification report: XGBoost 4s_0.5(none)
#               precision    recall  f1-score   support
#
#         void       0.53      0.62      0.57       405
#     non-void       0.77      0.70      0.73       745
#
#     accuracy                           0.67      1150
#    macro avg       0.65      0.66      0.65      1150
# weighted avg       0.69      0.67      0.68      1150
#
#
# Testing oversample_smote...
# Classification report: XGBoost 4s_0.5(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.58      0.63      0.61       441
#     non-void       0.76      0.72      0.74       709
#
#     accuracy                           0.69      1150
#    macro avg       0.67      0.68      0.67      1150
# weighted avg       0.69      0.69      0.69      1150
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 4s_0.5(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.62      0.64      0.63       461
#     non-void       0.75      0.74      0.74       689
#
#     accuracy                           0.70      1150
#    macro avg       0.69      0.69      0.69      1150
# weighted avg       0.70      0.70      0.70      1150
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  73%|███████▎  | 11/15 [07:53<01:44, 26.05s/it]
# Classification report: XGBoost 4s_0.5(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.62      0.64      0.63       461
#     non-void       0.75      0.73      0.74       689
#
#     accuracy                           0.70      1150
#    macro avg       0.68      0.69      0.68      1150
# weighted avg       0.70      0.70      0.70      1150
#
# Analysing 4s_0.8
#
# Testing none...
# Classification report: XGBoost 4s_0.8(none)
#               precision    recall  f1-score   support
#
#         void       0.57      0.65      0.61      1066
#     non-void       0.77      0.71      0.74      1789
#
#     accuracy                           0.69      2855
#    macro avg       0.67      0.68      0.67      2855
# weighted avg       0.70      0.69      0.69      2855
#
#
# Testing oversample_smote...
# Classification report: XGBoost 4s_0.8(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.61      0.63      0.62      1175
#     non-void       0.73      0.72      0.72      1680
#
#     accuracy                           0.68      2855
#    macro avg       0.67      0.67      0.67      2855
# weighted avg       0.68      0.68      0.68      2855
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 4s_0.8(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.59      0.65      0.62      1111
#     non-void       0.76      0.72      0.74      1744
#
#     accuracy                           0.69      2855
#    macro avg       0.68      0.68      0.68      2855
# weighted avg       0.70      0.69      0.69      2855
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  80%|████████  | 12/15 [08:25<01:22, 27.63s/it]
# Classification report: XGBoost 4s_0.8(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.59      0.63      0.61      1144
#     non-void       0.74      0.71      0.73      1711
#
#     accuracy                           0.68      2855
#    macro avg       0.67      0.67      0.67      2855
# weighted avg       0.68      0.68      0.68      2855
#
# Analysing 5s_no
#
# Testing none...
# Classification report: XGBoost 5s_no(none)
#               precision    recall  f1-score   support
#
#         void       0.56      0.66      0.60       163
#     non-void       0.80      0.72      0.76       302
#
#     accuracy                           0.70       465
#    macro avg       0.68      0.69      0.68       465
# weighted avg       0.71      0.70      0.70       465
#
#
# Testing oversample_smote...
# Classification report: XGBoost 5s_no(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.62      0.63      0.62       188
#     non-void       0.74      0.74      0.74       277
#
#     accuracy                           0.69       465
#    macro avg       0.68      0.68      0.68       465
# weighted avg       0.69      0.69      0.69       465
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 5s_no(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.70      0.65      0.67       206
#     non-void       0.73      0.78      0.75       259
#
#     accuracy                           0.72       465
#    macro avg       0.71      0.71      0.71       465
# weighted avg       0.72      0.72      0.72       465
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  87%|████████▋ | 13/15 [08:35<00:44, 22.42s/it]
# Classification report: XGBoost 5s_no(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.61      0.61      0.61       191
#     non-void       0.73      0.73      0.73       274
#
#     accuracy                           0.68       465
#    macro avg       0.67      0.67      0.67       465
# weighted avg       0.68      0.68      0.68       465
#
# Analysing 5s_0.5
#
# Testing none...
# Classification report: XGBoost 5s_0.5(none)
#               precision    recall  f1-score   support
#
#         void       0.59      0.68      0.63       327
#     non-void       0.80      0.73      0.77       581
#
#     accuracy                           0.72       908
#    macro avg       0.70      0.71      0.70       908
# weighted avg       0.73      0.72      0.72       908
#
#
# Testing oversample_smote...
# Classification report: XGBoost 5s_0.5(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.60      0.64      0.62       353
#     non-void       0.76      0.73      0.74       555
#
#     accuracy                           0.69       908
#    macro avg       0.68      0.68      0.68       908
# weighted avg       0.70      0.69      0.70       908
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 5s_0.5(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.63      0.65      0.64       363
#     non-void       0.76      0.74      0.75       545
#
#     accuracy                           0.70       908
#    macro avg       0.69      0.70      0.69       908
# weighted avg       0.71      0.70      0.71       908
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results:  93%|█████████▎| 14/15 [08:51<00:20, 20.58s/it]
# Classification report: XGBoost 5s_0.5(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.62      0.66      0.64       355
#     non-void       0.77      0.74      0.75       553
#
#     accuracy                           0.71       908
#    macro avg       0.69      0.70      0.70       908
# weighted avg       0.71      0.71      0.71       908
#
# Analysing 5s_0.8
#
# Testing none...
# Classification report: XGBoost 5s_0.8(none)
#               precision    recall  f1-score   support
#
#         void       0.57      0.65      0.61       846
#     non-void       0.77      0.70      0.74      1422
#
#     accuracy                           0.69      2268
#    macro avg       0.67      0.68      0.67      2268
# weighted avg       0.70      0.69      0.69      2268
#
#
# Testing oversample_smote...
# Classification report: XGBoost 5s_0.8(oversample_smote)
#               precision    recall  f1-score   support
#
#         void       0.60      0.63      0.62       926
#     non-void       0.74      0.71      0.73      1342
#
#     accuracy                           0.68      2268
#    macro avg       0.67      0.67      0.67      2268
# weighted avg       0.68      0.68      0.68      2268
#
#
# Testing undersample_tomek_links...
# Classification report: XGBoost 5s_0.8(undersample_tomek_links)
#               precision    recall  f1-score   support
#
#         void       0.60      0.66      0.63       881
#     non-void       0.77      0.72      0.74      1387
#
#     accuracy                           0.70      2268
#    macro avg       0.68      0.69      0.69      2268
# weighted avg       0.70      0.70      0.70      2268
#
#
# Testing combined_smote_tomek...
# Generating classification reports from the cross validation results: 100%|██████████| 15/15 [09:18<00:00, 37.21s/it]
# Classification report: XGBoost 5s_0.8(combined_smote_tomek)
#               precision    recall  f1-score   support
#
#         void       0.61      0.64      0.63       930
#     non-void       0.74      0.72      0.73      1338
#
#     accuracy                           0.69      2268
#    macro avg       0.68      0.68      0.68      2268
# weighted avg       0.69      0.69      0.69      2268
