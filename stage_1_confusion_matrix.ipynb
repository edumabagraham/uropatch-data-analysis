# %%
import pickle
import pandas as pd

# %%
with open('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/imb_files/dt_cv_results.pkl', 'rb') as f:
    dt_results = pickle.load(f)
with open('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/imb_files/rf_cv_results.pkl', 'rb') as f:
    rf_results = pickle.load(f)
with open('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/imb_files/xgb_cv_results.pkl', 'rb') as f:
    xgb_results = pickle.load(f)

# %%
rf_results['3s_no']
# Out:
# {'none': {'mean_accuracy': np.float64(0.7042694068635539),
#   'std_accuracy': np.float64(0.10525805629218046),
#   'mean_recall_minority': np.float64(0.5870312780514302),
#   'std_recall_minority': np.float64(0.15244992099528623),
#   'mean_f1_minority': np.float64(0.6160018285586047),
#   'std_f1_minority': np.float64(0.10736926798457351),
#   'mean_f1_majority': np.float64(0.7522497873831994),
#   'std_f1_majority': np.float64(0.10762206834928223),
#   'macro_f1': np.float64(0.684125807970902),
#   'std_macro_f1': np.float64(0.10071235655829341),
#   'weighted_f1': np.float64(0.7013224716766865),
#   'std_weighted_f1': np.float64(0.10743667530159691),
#   'fold_details': [{'fold': 0,
#     'recall_void': 0.8181818181818182,
#     'precision_# split datavoid': 0.5294117647058824,
#     'f1_void': 0.6428571428571429,
#     'macro_f1': 0.7619047619047619,
#     'weighted_f1': 0.8341836734693876,
#     'accuracy': 0.8214285714285714,
#     'precision_non_void': 0.9487179487179487,
# ...
