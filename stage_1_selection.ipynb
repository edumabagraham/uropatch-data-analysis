# %%
import pickle
import pandas as pd

# %%
with open('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/imb_files/dt_cv_results.pkl', 'rb') as f:
    dt_results = pickle.load(f)
with open('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/imb_files/rf_cv_results.pkl', 'rb') as f:
    rf_results = pickle.load(f)
with open('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/imb_files/xgb_cv_results.pkl', 'rb') as f:
    xgb_results = pickle.load(f)

# %%
imb_tech = ['none', 'oversample_smote', 'undersample_tomek_links', 'combined_smote_tomek']
models = ['Decision Tree', 'Random Forest', 'XGBoost']

# %%
# Combine all model results into one dictionary
all_results = {
    'Decision Tree': dt_results,
    'Random Forest': rf_results,
    'XGBoost': xgb_results
}

# %%
import pandas as pd
import numpy as np

def format_cv_results_separate_models(model_results_dict, imb_tech, models):
    """
    Convert cross-validation results from separate model dictionaries to tabular format.
    
    Parameters:
    model_results_dict: Dictionary where keys are model names and values are 
                    dictionaries with structure {dataset: {imbalance_technique: {metrics...}}}
    imb_tech: List of imbalance handling techniques
    models: List of model names
    
    Returns:
    pandas.DataFrame: Formatted results table
    """
    
    formatted_data = []
    
    # Iterate through each model
    for model in models:
        if model in model_results_dict:
            model_data = model_results_dict[model]
            
            
            # Iterate through each dataset for this model
            for dataset, dataset_results in model_data.items():
                
                # Iterate through each imbalance technique
                for technique in imb_tech:
                    # Check if this technique exists in the results
                    if technique in dataset_results:
                        technique_results = dataset_results[technique]
                        
                        recall_void_avg = technique_results.get('mean_recall_minority', 0)
                        recall_void_std = technique_results.get('std_recall_minority', 0)
                        accuracy_avg = technique_results.get('mean_accuracy', 0)
                        accuracy_std = technique_results.get('std_accuracy', 0)
                        f1_void_avg = technique_results.get('mean_f1_minority', 0)
                        f1_void_std = technique_results.get('std_f1_minority', 0)
                        macro_f1_avg = technique_results.get('macro_f1', 0)
                        macro_f1_std = technique_results.get('std_macro_f1', 0)
                        weighted_f1_avg = technique_results.get('weighted_f1', 0)
                        weighted_f1_std = technique_results.get('std_weighted_f1', 0)
                        
                        if technique == "none":
                            technique = "Baseline (none)"
                        elif technique == "oversample_smote":
                            technique = "SMOTE"
                        elif technique == "undersample_tomek_links":
                            technique = "TomekLinks"
                        elif technique == "combined_smote_tomek":
                            technique = "SMOTETomek"
                        
                        # Add row to formatted data
                        formatted_data.append({
                            'Dataset': dataset,
                            'Model': model,
                            'Imbalance Technique': technique,
                            'F1-Score (avg)': round(f1_void_avg, 5),
                            'F1-Score (std)': round(f1_void_std, 5),
                            'F1-Score (avg:std)': round(f1_void_avg/f1_void_std, 5),
                            'Recall (avg)': round(recall_void_avg, 5),
                            'Recall (std)': round(recall_void_std, 5),
                            'Recall (avg:std)': round(recall_void_avg/recall_void_std, 5),
                            'Accuracy (avg)': round(accuracy_avg, 5),
                            'Accuracy (std)': round(accuracy_std, 5),
                            'Accuracy (avg:std)': round(accuracy_avg/accuracy_std, 5),
                            'Macro F1 (avg)': round(macro_f1_avg, 5),
                            'Macro F1 (std)': round(macro_f1_std, 5),
                            'Macro F1 (avg:std)': round(macro_f1_avg/macro_f1_std, 5),
                            'Weighted F1 (avg)': round(weighted_f1_avg, 5),
                            'Weighted F1 (std)': round(weighted_f1_std, 5),
                            'Weighted F1 (avg:std)': round(weighted_f1_avg/weighted_f1_std, 5)
                            
                        })
                        
                        
    
    # Create DataFrame
    df = pd.DataFrame(formatted_data)
    
    # Sort by Dataset, Model, and Imbalance Technique for better organization
    # df = df.sort_values(['Dataset', 'Model', 'Imbalance Technique']).reset_index(drop=True)
    
    return df


print("Function ready to use for separate model dictionaries.")
# Out:
# Function ready to use for separate model dictionaries.

# %%
df = format_cv_results_separate_models(all_results, imb_tech, models)
df
# Out:
#     Dataset          Model Imbalance Technique  F1-Score (avg)  \
# 0     1s_no  Decision Tree     Baseline (none)         0.51511
# 1     1s_no  Decision Tree               SMOTE         0.49797
# 2     1s_no  Decision Tree          TomekLinks         0.50410
# 3     1s_no  Decision Tree          SMOTETomek         0.49839
# 4    1s_0.5  Decision Tree     Baseline (none)         0.49443
# ..      ...            ...                 ...             ...
# 175  5s_0.5        XGBoost          SMOTETomek         0.61933
# 176  5s_0.8        XGBoost     Baseline (none)         0.56280
# 177  5s_0.8        XGBoost               SMOTE         0.60013
# 178  5s_0.8        XGBoost          TomekLinks         0.58501
# 179  5s_0.8        XGBoost          SMOTETomek         0.58889
#
#      F1-Score (std)  F1-Score (avg:std)  Recall (avg)  Recall (std)  \
# 0           0.09567             5.38402       0.52845       0.12156
# 1           0.06870             7.24861       0.51003       0.08139
# 2           0.05547             9.08804       0.51556       0.09506
# 3           0.05968             8.35051       0.50417       0.07235
# 4           0.07688             6.43133       0.49643       0.09836
# ..              ...                 ...           ...           ...
# 175         0.08509             7.27828       0.63148       0.14881
# 176         0.14618             3.84995       0.53342       0.18773
# 177         0.14434             4.15774       0.58973       0.19008
# 178         0.12997             4.50123       0.59028       0.17953
# 179         0.13613             4.32607       0.57905       0.18591
#
#      Recall (avg:std)  Accuracy (avg)  Accuracy (std)  Accuracy (avg:std)  \
# 0             4.34710         0.61332         0.07208             8.50843
# 1             6.26621         0.59437         0.06415             9.26518
# 2             5.42356         0.60048         0.06843             8.77466
# 3             6.96817         0.59999         0.04775            12.56515
# 4             5.04692         0.59925         0.06045             9.91235
# ..                ...             ...             ...                 ...
# 175           4.24363         0.68912         0.08510             8.09744
# 176           2.84137         0.65871         0.10399             6.33456
# 177           3.10252         0.67181         0.11684             5.74989
# 178           3.28792         0.65320         0.10263             6.36437
# 179           3.11463         0.66695         0.10233             6.51760
#
#      Macro F1 (avg)  Macro F1 (std)  Macro F1 (avg:std)  Weighted F1 (avg)  \
# 0           0.59190         0.07050             8.39586            0.61447
# 1           0.57333         0.05803             9.88031            0.59752
# 2           0.58123         0.05941             9.78347            0.60286
# 3           0.57772         0.04320            13.37331            0.60305
# 4           0.57821         0.05903             9.79466            0.60003
# ..              ...             ...                 ...                ...
# 175         0.66822         0.08146             8.20314            0.69198
# 176         0.63471         0.10755             5.90165            0.65264
# 177         0.65291         0.11790             5.53784            0.66807
# 178         0.63727         0.10265             6.20841            0.65201
# 179         0.64721         0.10404             6.22060            0.66341
#
#      Weighted F1 (std)  Weighted F1 (avg:std)
# 0              0.07582                8.10411
# 1              0.06841                8.73392
# 2              0.07350                8.20255
# 3              0.04950               12.18256
# 4              0.06303                9.52016
# ..                 ...                    ...
# 175            0.08312                8.32507
# 176            0.10848                6.01614
# 177            0.11959                5.58627
# 178            0.10498                6.21080
# 179            0.10391                6.38437
#
# [180 rows x 18 columns]

# %% [markdown]
# <!-- Sort in ascending order based on ### Recall Void (avg:std) -->

# %%
df_sorted_f1_score = df.sort_values(by='F1-Score (avg)', ascending=False).reset_index(drop=True)
df_sorted_f1_score
# Out:
#     Dataset          Model Imbalance Technique  F1-Score (avg)  \
# 0     3s_no  Random Forest          SMOTETomek         0.65463
# 1     3s_no  Random Forest          TomekLinks         0.64932
# 2     5s_no  Random Forest          SMOTETomek         0.64600
# 3    5s_0.5  Random Forest          SMOTETomek         0.63674
# 4    2s_0.5  Random Forest          TomekLinks         0.63299
# ..      ...            ...                 ...             ...
# 175   4s_no  Decision Tree          TomekLinks         0.48033
# 176   4s_no  Decision Tree               SMOTE         0.46878
# 177  1s_0.8  Decision Tree          TomekLinks         0.46665
# 178   3s_no  Decision Tree               SMOTE         0.45315
# 179   5s_no  Decision Tree               SMOTE         0.42964
#
#      F1-Score (std)  F1-Score (avg:std)  Recall (avg)  Recall (std)  \
# 0           0.11035             5.93250       0.65931       0.15173
# 1           0.11494             5.64917       0.67013       0.13822
# 2           0.14493             4.45720       0.69436       0.21260
# 3           0.07456             8.53973       0.63052       0.09716
# 4           0.09120             6.94092       0.61569       0.08527
# ..              ...                 ...           ...           ...
# 175         0.08880             5.40940       0.47833       0.11522
# 176         0.16381             2.86181       0.45923       0.17398
# 177         0.13956             3.34379       0.45279       0.16085
# 178         0.08750             5.17910       0.47719       0.08989
# 179         0.15613             2.75178       0.43716       0.20697
#
#      Recall (avg:std)  Accuracy (avg)  Accuracy (std)  Accuracy (avg:std)  \
# 0             4.34519         0.71523         0.11371             6.28968
# 1             4.84817         0.70601         0.11424             6.18028
# 2             3.26609         0.70813         0.11867             5.96710
# 3             6.48937         0.70222         0.09468             7.41667
# 4             7.22064         0.71519         0.07346             9.73578
# ..                ...             ...             ...                 ...
# 175           4.15144         0.58609         0.08924             6.56757
# 176           2.63954         0.58564         0.12898             4.54035
# 177           2.81495         0.60316         0.08105             7.44153
# 178           5.30881         0.53929         0.07104             7.59168
# 179           2.11216         0.57597         0.10480             5.49602
#
#      Macro F1 (avg)  Macro F1 (std)  Macro F1 (avg:std)  Weighted F1 (avg)  \
# 0           0.70145         0.10970             6.39423            0.71559
# 1           0.69292         0.11097             6.24400            0.70883
# 2           0.68961         0.11829             5.82965            0.70849
# 3           0.68157         0.08906             7.65290            0.70433
# 4           0.69362         0.07338             9.45180            0.71571
# ..              ...             ...                 ...                ...
# 175         0.56415         0.08351             6.75581            0.58743
# 176         0.55885         0.12786             4.37088            0.58257
# 177         0.57155         0.09009             6.34414            0.59608
# 178         0.51770         0.07114             7.27703            0.54349
# 179         0.53553         0.10062             5.32232            0.56846
#
#      Weighted F1 (std)  Weighted F1 (avg:std)
# 0              0.11536                6.20293
# 1              0.11512                6.15754
# 2              0.12022                5.89318
# 3              0.09310                7.56548
# 4              0.07070               10.12343
# ..                 ...                    ...
# 175            0.09244                6.35505
# 176            0.13322                4.37304
# 177            0.09200                6.47916
# 178            0.07225                7.52207
# 179            0.11751                4.83734
#
# [180 rows x 18 columns]

# %%
# Save the DataFrame to a CSV file
df_sorted_f1_score.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/uropatch-data-analysis/imb_files/f1_score_sorted_stage_1.csv', index=False)
